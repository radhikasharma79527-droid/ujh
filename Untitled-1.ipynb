# %%
print("hello")
# Out:
# hello

# %%
print("my name is radhika")

print(10+10)
# Out:
# my name is radhika
# 20

# %%
# Integer (whole number)
age = 20

# Float (decimal number)
height = 5.5

# String (text)
name = "Radhika"

# Boolean (True or False)
student = True

# Print all of them
print(age)
print(height)
print(name)
print(student)
# Out:
# 20
# 5.5
# Radhika
# True

# %%
a = 10
b = 18
print (a+b);
a = 19
b = 15
print (a-b);
# Out:
# 28
# 4

# %%
#  addd subtract multply and divide two number . find square of a number find the remainder
a = 10
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %%
number = 6

print("Square:", number ** 2)
# Out:
# Square: 36

# %%
#remainder
a = 17
b = 5

print("Remainder:", a % b)
# Out:
# Remainder: 2

# %%
marks = 87
if marks > 35:
    print("you passed")
# Out:
# you passed

# %%
marks = 87
if marks >35:
    print("you passed")
else:
    print("you failed.try again")
# Out:
# you passed

# %%
name = "radhika"
age = 13
marks = 88.9
#complex number
a = (9,8)
print (type(name))
print ("type of age",type(age))
print ("type of marks",type(marks))
print ("type of a",type(a))
b= complex (4,6)
# Out:
# <class 'str'>
# type of age <class 'int'>
# type of marks <class 'float'>
# type of a <class 'tuple'>

# %%
marks = [333,56,79]
print(marks)
print(type(marks))
print(marks[0])
number = [22.7,88.9,99.8]
print(number)
print(type(number))
print(number[1])
print (len(number))#list =len
# Out:
# [333, 56, 79]
# <class 'list'>
# 333
# [22.7, 88.9, 99.8]
# <class 'list'>
# 88.9
# 3

# %%
#list in python = store all values example integer,float,string,
student = ["radhika",19,"himachal"]
print(list(student))
# Out:
# ['radhika', 19, 'himachal']

# %%
#list slicing [:]
marks = [77,99,88,77,65,76]
print(marks[1:4])
print(marks[-3:-1])
# Out:
# [99, 88, 77]
# [77, 65]

# %%
#list method
#1. append (to add number in list)
marks =[1,2,3,4]
marks.append(5)
print(marks)
#2.sort assending,in decending order some difference we have to write reverse = true , string is alos possible like a , b,d,r
marks =[98,65,44,66,34,87]
print(marks.sort())
print(marks)
#now decending order
print(marks.sort(reverse=True))
print(marks)
name = [ "radhika","aradhya","kritik","shivam"]
print(name.sort())
print(name)
print(name.sort(reverse = True))
print(name)

# reverse method 
marks =[98,87,67]
marks.reverse()
print(marks)

#insert mathod 
marks. insert(87,99)
print(marks)

#remove
marks.remove(98)
print(marks)

#pop
marks.pop(1)
print(marks)
list.
# Out:
# [1, 2, 3, 4, 5]
# None
# [34, 44, 65, 66, 87, 98]
# None
# [98, 87, 66, 65, 44, 34]
# None
# ['aradhya', 'kritik', 'radhika', 'shivam']
# None
# ['shivam', 'radhika', 'kritik', 'aradhya']
# [67, 87, 98]
# [67, 87, 98, 99]
# [67, 87, 99]
# [67, 99]

# %%
# printing the same line 
print('''python is easy and we have to understand it how it work there may be same logic''')
print("python ",end=" ")
print("programing")
# Out:
# python is easy and we have to understand it how it work there may be same logic
# python  programing

# %% [markdown]
# changing separator

# %%
print("apple","banana","mango",sep="|")
# Out:
# allple|banana|mango

# %%
#different data 
print("age:",19)
print("name:","riyanshi")
print("marks:",99.7)
print("passed:",True)
# Out:
# age: 19
# name: riyanshi
# marks: 99.7
# passed: True

# %%
#comments
print("hie i love you beautiful.")
# Out:
# hie i love you beautiful.

# %% [markdown]
# #variable rules
# * underscore allowed
#
# * numbers allowed after letters
#
# * spaces not allowed

# %%
student_name ="suamn"
age = 19
print(student_name)
print(age)
# Out:
# suamn
# 19

# %%
#data type
age = 77
name = "rohit"
height = 5.4
is_student = True
complexs = 2+5j
print(type(age))
print(type(name))
print(type(height))
print(type(is_student))
print(type(complexs))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'complex'>

# %%
name = "rahul"
print(name)
name = "r"
print(name)
# Out:
# rahul
# r

# %%
#Arithmetic operators
a=98
b=67
print("addition=",a+b)
print("subtraction=",a-b)
print("multiplication=",a*b)
print("division=",a/b)

a=20
b=5
print("remainder=",(a%b))
print("power=",a**b)
print("floor division=",a//b)
# Out:
# addition= 165
# subtraction= 31
# multiplication= 6566
# division= 1.462686567164179
# remainder= 0
# power= 3200000
# floor division= 4

# %%
#Assignement operator
x = 10
print(x)
x += 5
print(x)
x -= 2
print(x)
x *= 3
print(x)
x /= 2
print(x)
x %=6
print(x)
# Out:
# 10
# 15
# 13
# 39
# 19.5
# 1.5

# %%
# comparison operator
a = 67
b = 54
print(a==b)
print(a>b)
print(a>=b)
print(a<=b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# True
# False
# True
# True
# False

# %%
marks = 33
attandance = 98
print(marks > 40 and attandance > 75)
print(marks > 92 or attandance > 75)
print(not(marks > 10))
# Out:
# False
# True
# False

# %%
#membership operators
fruits = ["Apple","mango","grapes"]
print("Apple" in fruits)
print("guava" in fruits)
print("orange" in fruits)
# Out:
# True
# False
# False

# %%
#identity operators == compares values
a = [12,56]
a = b
c = [12,56]
print(a is b)
print(a is c)
print(a==c)
# Out:
# True
# False
# False

# %%
print("hello world")
# Out:
# hello world
